# %%
#Drive connection
# !sudo echo -ne '\n' | sudo add-apt-repository ppa:alessandro-strada/ppa >/dev/null 2>&1 # note: >/dev/null 2>&1 is used to supress printing
# !sudo apt update >/dev/null 2>&1
# !sudo apt install google-drive-ocamlfuse >/dev/null 2>&1
# !google-drive-ocamlfuse
# !sudo apt-get install w3m >/dev/null 2>&1 # to act as web browser
# !xdg-settings set default-web-browser w3m.desktop >/dev/null 2>&1 # to set default browser
# %cd /content
# !mkdir gdrive
# %cd gdrive
# !mkdir "My Drive"
# !google-drive-ocamlfuse "/content/gdrive/My Drive"
# Out:
# /usr/bin/xdg-open: 869: www-browser: not found
# /usr/bin/xdg-open: 869: links2: not found
# /usr/bin/xdg-open: 869: elinks: not found
# /usr/bin/xdg-open: 869: links: not found
# /usr/bin/xdg-open: 869: lynx: not found
# /usr/bin/xdg-open: 869: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=LnC8Fc8Tev0akASZSB7jUOHYjHtn5RMRhh92G9fuD8I'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /bin/sh: 1: open: not found
# Cannot retrieve auth tokens.
# ...

# %%
import pandas as pd

# %% [markdown]
# # Annotation to the data cluster of the Raw data

# %%
df1 = pd.read_csv('/content/gdrive/My Drive/Meta_Asr/Data_Annotation/Audios_Clusturing/ClusterData_RawData_MetaFeatureClustered.csv')
df2 = pd.read_csv('/content/gdrive/My Drive/Meta_Asr/Data_Annotation/Audios_Clusturing/ClusterData_PreProcessed_MetaFeatureClustered.csv')

# %%
df1_groundTruth_Text=["A mother and a wife.Yeah, an airline stewardess.So I was so set as a 13 year old.",
                  "Who should protect you, not protecting you.And then you understand people's values.And I think the biggest thing I learned is, like, if.",
                  "Touch them from the back and they startle easily.Night Terrors, there's a lot ofthings change in grades at school.If you had an A student and allof a sudden, they're a C or.",
                  "Was the word suck.So if somebody used that word just incasual conversation, I couldn't hear it without.",
                  "Long I was there, it seemed like forever.He said that this was going tobe a secret between us and.",
                  "As a survivor.I'm here today as an advocate.I'm here today to encourage our people toseek the help that's available to them.",
                  "It and actually wanting it becauseit was a form of affection. It was a form of love.",
                  "I just learned to fight when Isay that I had four different sexual.",
                  "I received.Becoming a mother taught me how to love.That unconditional love was there.",
                  "Remember walking up the steps thinking, I'm not going togo up there and there were two of us. Because I would.",
                  "Organizations out there doing brilliant workworking with our young people.But just be mindful, too, that you don'thave to be referred to a professional toget the support that you need.",
                  "Feeling of empathy that goes out and there's an enormoussense of respect what you want to try to do.",
                  "Me.Urinated on me.Anything that she wanted to doto further her sexual pleasure.Gratification and anything that.",
                  "You know, like we were buddies.He said we should get together again sometime.Maybe go to a movie, like.",
                  "I will never forget the horrors of what happened to me.",
                  "Gordon was in the doorway, so I said hi.And he said hi back and commented onmy playing with his dad, living in the.",
                  "I'm angry at you, too.You're not the mother of the year.And so I think what I've learnedis just how to let go right?And how to be honest with what is."


                  ]

# %%
df1['GroundTruth_Text']=df1_groundTruth_Text

# %%
df1.to_csv('/content/gdrive/My Drive/Meta_Asr/Data_Annotation/Audios_Clusturing/ClusterData_RawData_MetaFeatureClustered.csv',index=0)

# %%
df1

# %% [markdown]
# # Annotation to the data cluster of the preProcessing data

# %%
df2_groundTruth_Text=["I never really blamed him.I blamed myself.And that self blame, over time,became a kind of selfhatred.",
                       "I began to rewrite the film with this back and forth.In time and in memory, thethe film actually became much more.",
                       "Some may find the details disturbing.Nearly a decade after his death,multiple Grammy winner Michael Jackson's.",
                       "In 2005 during the criminal trial.The reason why Wade changed his story.And that's what it looks like.And I can understand why people.",
                       "I wasn't being as open as I used to be.Or it looked like maybe I was keeping secretsor I just wasn't sharing how I felt.Maybe if someone had come to me and said, Are.",
                       "Theirs to come out and state this.And they're still in court with the estatesuing them for hundreds of millions of dollars.Jackson's estate is suing HBO for 100.",
                       "Say yes, yes or not like that.I was very scared.I was shaking and shaking and shaking till I dropped.It was kind of scary, but.",
                       "I had a lot more independence.I wasn't hanging around with thefamily as much in those scenarios.I'd be playing with my own friends,and eventually I just kind of.",
                       "The Way that I see our lives asbeing parallel is that we both hadthis formative, traumatic experience, one that really.",
                       "To usher me out when he raised his fingerto his lips and swore me to a secret.Michael's old secret is now the subjectof a one-man play he wrote.",
                       "Started to touch me, and it started with just a littlepat on the head, a little stroke on your lap.And before you know it, they work.They move their way to progressive.",
                       "How can you protect yourself against aa family member, who's perpetrating the crime?You know, family members who you couldhave grown up with all your life.Uncles, aunts, your mama.",
                       "And asked me what I might buy with it.And I told him a fried pie.And then he opened the door andhe ushered me out and I went.",
                       "Of that, I think my mother put forward thatreally centered her on she survived this terrible marriage.This is about the three of us together,meaning her and me and my sister.And I think secrets are.",
                       "When I think about it, it was most likelyjust shoved off the carpet even as a child.That was imposed on me from a very young age.You don't talk about your feelings.You don't talk about it.",
                       "hat part of the story.Soon after this turning point and this awakeningthat, in fact, the relationship I had was."]

# %%
df2['GroundTruth_Text']=df2_groundTruth_Text

# %%
df2.to_csv("/content/gdrive/My Drive/Meta_Asr/Data_Annotation/Audios_Clusturing/ClusterData_PreProcessed_MetaFeatureClustered.csv",index=0)
